# %% [markdown]
# # Informacje podstawowe:
# Egzamin składa się z 7 ćwiczeń, łącznie do uzyskania jest 100 pkt:
# 1.   Pierwsze 4 są krótsze i pozwalają uzyskać 10 puntków - każde wymaga użycia pojedynczego elementu składni Python.
# 2.   Ostatnie 3 są bardziej złożone i wymagają łączniea różnych struktur etc.
#
# Ćwiczenia najlepiej wykonywać w Colab - pamiętamy, że w takim wypadku działa autozapis. W razie problemów plik z ostatnią wersją znajduje się na dysku Google w folderze *Colab Notebooks*
#
# Poproszę o wysłanie wypełnionego arkusza na adres:
# jakub.rybacki@uw.edu.pl

# %% [markdown]
# ### 1. Operacje na listach (10 pkt)
# Naszym celem jest stworzyć listę z numerów 1 , 2, 8, 3, 12, 10, 14, 16
#
# Nastęnie:
# 1.   Dodajemy na koniec listy liczbę 100 i wyświetlamy listę.
# 2.   Zamieniamy 100 na 20 i wyświetlamy listę.
# 3.   Przed 20 wstawiamy liczbę 18 i wyświetlamy listę
# 4.   Usuwamy liczbę 2 i wyświetlamy listę
# 5.   Wyświetlamy od 3 do 5 liczby znajdującej się na liście.
#
# Rezultatem powinno być 5 list.

# %% [markdown]
# ### 2. Indeksowanie (10 pkt.)
# Wykonajmy polecenie, o które prosi zmienna Text

# %%
Text = "Wydrukuj pierwszych 20% znaków z zawartości tego tekstu"

# %% [markdown]
# ### 3. Usuwanie duplikatów (10 pkt.)
# Do dyspozycji mamy długą listę, która zawierać będzie złączenia liter A, B, C oraz cyfr. Elementy na liście powtarzają się.
#
# Chcemy mieć tylko unikatowe wartości - z usuniętymi duplikatami.

# %%
lista_duplikaty = ["A9", "A3", "B7", "B8", "B7", "C0", "B0", "A3", "B5", "A7", "A4", "C3", "B7", "A9", "C8", "B10", "A2", "C0", "A9", "A5", "A6", "A3", "B10", "A1", "A7", "C10", 
                   "C3", "A8", "C5", "B0", "B4", "C8", "C8", "B1", "B7", "B6", "B0", "A0", "B9", "C7", "B8", "C8", "C5", "C6", "C6", "A1", "C8", "C3", "B1", "B6", "A10", "A9", "A9",
                   "B7", "C9", "A5", "C4", "B4", "B6", "B5", "A4", "C3", "B6", "B9", "C5", "C2", "C1", "A1", "B9", "C4", "C7", "B6", "B7", "B4", "C3", "C3", "C9", "B10", "A7", "B8", 
                   "B2", "C2", "B10", "A7", "B0", "C3", "C7", "C4", "A4", "A9", "C8", "B4", "B3", "C4", "C10", "A0", "B10", "A7", "C1", "B5", "C8", "A3", "C2", "B1", "A3", "A10", 
                   "C3", "A7", "C10", "C9", "C3", "B9", "A5", "B2", "C10", "A7", "A1", "A4", "B7", "C5", "C5", "A2", "A1", "C7", "A9", "B4", "A2"]

# %% [markdown]
# ### 4. Pętle (10 pkt.)
#
# Napisz pętle, która usunie z listy wszystkie wystąpienia słowa "Do usunięcia".
#
# Pętla ma działać niezależnie od tego, ile takich słów wystąpi w tekście.

# %%
lista_usuwanie = [0.09, 0.5, "Do usunięcia", 0.6, "Do usunięcia", 0.66, "Do usunięcia", 0.08, 0.66, 0.21, 0.49, 0.31, 0.25, 
                  "Do usunięcia", 0.61, 0.61, 0.47, 0.57, 0.09, 0.26, "Do usunięcia", 0.78, 0.71, 0.35, 0.36, 0.49, 
                  "Do usunięcia", "Do usunięcia", 0.34, 0.02, ]

# %% [markdown]
# ### 5. Funkcję + listy (20 pkt.)
#
# Napisz funkcję, która zliczy sumę wszystkich cyfr z danego ciągu znaków.
#
# **Przykład:**
# dla 1123 działanie to 1 + 1 + 2 + 3, a wynik 7.
#
# Następnie wykonaj funkcję na wszystkich elementach 3 list.

# %%
lista1 = ["1234", "8872", "890303"]
lista2 = ["1510", "1871", "89030301"]
lista3 = ["2468", "9852", "8903030332"]

# %% [markdown]
# ### 6. Słownik (20 pkt. )
# Dysponujemy tekstem piosenki Kazika. W pierwszej kolejności chcemy rozbić go na listę słów oraz usunąć te wyrazy, które mają mniej niż 4 znaki.
#
# Następnie stwórzmy słownik, gdzie policzymy ilość wystąpień kolejnych słów.

# %%
piosenka = """Maciek ja tylko żartowałem Gdy tobie z sobą iść kazałem Tam nie było żadnych pieniędzy Była nędza nic więcej Tyle razy o tym myślałem
           Maciek ja tylko żartowałem Nie nie nie zwariowałem Ani tym bardziej nie oszalałem Maciek ja tylko żartowałem Maciek ja tylko żartowałem 
           Maciek ja tylko żartowałem Maciek ja tylko żartowałem Maciek ja tylko żartowałem Maciek ja tylko żartowałem Maciek ja tylko żartowałem
          Maciek ja tylko żartowałem Maciek ja tylko żartowałem Nigdy ciebie nie kochałem Kochałem setki innych facetów Z tobą to jednak nie to"""

# %% [markdown]
# ### 7. Listy + lambda (20 pkt.)
#
# Wyobraźmy sobie taki przypadek - pytamy respondentów o to na kogo zagłosują na wyborach. Następnie z jakim prawdopodobieństwem pójdą na wybory.
#
# **Przed nami dwa zadania:**
#
# Część respondentów zamiast prawdopodbieństwa wpisała tekst z uzasadnieniem nieobecności. Odfiltrujmy tego typu odpowiedzi. Przyda sie funkcja *isinstance*.
#
# Następnie, chcemy ułożyć listę respondentów posortowaną w następujący sposób:
# 1.   W pierwszej kolejności grupujemy wyborców po partiach - obok siebie wystąpią wyborcy PiS, następnie PO, potem PSL
# 2.   Następnie chcemy ustawić od najbardziej zdecydowanego do najmniej.
#
# Najprościej jest przekazać do funkcji sortującej odpowiednią funkcję *lambda*.

# %%
wyniki_sondazu = [("Respondent1", "PiS", 45), ("Respondent2", "PO", 35),  ("Respondent3", "PSL", 55), ("Respondent3", "PiS", "Nie idę"), 
                  ("Respondent4", "PiS", 35), ("Respondent5", "PO", 75),  ("Respondent6", "PSL", "Wybory nic nie znaczą"), ("Respondent8", "PiS", 100)]
